# %% [markdown]
# # Abalone Case Study

# %%
import numpy as np
import pandas as pd
import scipy
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("abalone_project.csv")

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.head(3)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
#
#    Shell weight  Rings
# 0          0.15     15
# 1          0.07      7
# 2          0.21      9

# %%
df.sample(3)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4112   F    0.56     0.420   0.180        1.6645          0.7755
# 1826   I    0.31     0.215   0.075        0.1275          0.0565
# 1960   F    0.65     0.510   0.185        1.3750          0.5310
#
#       Viscera weight  Shell weight  Rings
# 4112          0.3500        0.4525      9
# 1826          0.0275        0.0360      7
# 1960          0.3840        0.3985     10

# %%
df.tail(3)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4174          0.2875         0.308      9
# 4175          0.2610         0.296     10
# 4176          0.3765         0.495     12

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
df=pd.DataFrame(data=df)
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Scatterplot:

# %%
sns.pairplot(df)

# %% [markdown]
# Observations:
#
# The pairplot gives us a visualization on scatter plot. Almost all the independant variables seem to have a positive relationship with Rings our target

# %% [markdown]
# ## Data Visualization:

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
Observations :

-There is no missing data present in the data set

# %% [markdown]
# ## Statistical Summary

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.Rings.unique()
# Out:
# array([15,  7,  9, 10,  8, 20, 16, 19, 14, 11, 12, 18, 13,  5,  4,  6, 21,
#        17, 22,  1,  3, 26, 23, 29,  2, 27, 25, 24], dtype=int64)

# %%
df.Rings.value_counts(ascending=True)
# Out:
# 26      1
# 25      1
# 2       1
# 29      1
# 1       1
# 24      2
# 27      2
# 22      6
# 23      9
# 21     14
# 3      15
# 20     26
# 19     32
# 18     42
# 4      57
# 17     58
# 16     67
# 15    103
# 5     115
# 14    126
# 13    203
# 6     259
# 12    267
# 7     391
# 11    487
# 8     568
# 10    634
# 9     689
# Name: Rings, dtype: int64

# %%
observations:

Mean of height columns is greater than median, hence it is right skewed. similar with Whole weight/shucked weight. 
Standard deviation is high in whole weight, shucked weight. It means data spread is high.

high gap between 75th percentile and max is present in rings, so few outliers is present

# %% [markdown]
# ### Bar plot

# %%
i = 0
x1= df.drop(['Rings','Sex'],axis=1)
y1= df['Rings']

# %%
y1
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
for col in x1.items():
    plt.figure(figsize=(10,5))
    sns.barplot(x=y1,y=col[i],data=df)
plt.tight_layout()
plt.show()

# %% [markdown]
# Observations:
#
# All the independant variables seem to have a positive relationship with Rings till rings 1-11 and afterwards seem to have constant or uneven pattern.

# %% [markdown]
# ### Count plot

# %%
plt.figure(figsize=(12,8))
sns.countplot(x ='Sex',data=df)
plt.xlabel('categories in the Sex column')
plt.ylabel('Count of Rows')
plt.show()

# %%
Observations:
    
In the 'Sex' column they are divided into 3 class namely M - Male, F - Female and I - Infant types.
Looking at the count plot there is not much data imbalance comparing the 3 categories.

# %% [markdown]
# ### Encoding 'Sex' Column since its a categorical Variable

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Sex']=le.fit_transform(df['Sex'])
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
le.inverse_transform([0,1,2])
# Out:
# array(['F', 'I', 'M'], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# 2    1528
# 1    1342
# 0    1307
# Name: Sex, dtype: int64

# %%
Observations:

Hence the categorical values have been encoded into 0,1 and 2 numerical data.
where 0 - Female , 1 - Infant and 2 - Male

# %% [markdown]
# ## checking Correlation

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5, fmt='.3f')
# Out:
# <AxesSubplot:>

# %%
df.corr()['Rings'].sort_values()
# Out:
# Sex              -0.034627
# Shucked weight    0.420884
# Viscera weight    0.503819
# Whole weight      0.540390
# Length            0.556720
# Height            0.557467
# Diameter          0.574660
# Shell weight      0.627574
# Rings             1.000000
# Name: Rings, dtype: float64

# %% [markdown]
# Observations:
#
# All the independant variables are showing high positive ccorrelation with the Rings target variable apart from 'Sex' Column which is a categorical encoded variable.
#
# It looks like the features column is showing multi collinearity. We will use VIF method to check multi collinearity

# %% [markdown]
# # Checking Outliers

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
df.plot(kind='box',subplots=True,layout=(3,4),figsize=(15,25))
# Out:
# Sex                  AxesSubplot(0.125,0.657941;0.168478x0.222059)
# Length            AxesSubplot(0.327174,0.657941;0.168478x0.222059)
# Diameter          AxesSubplot(0.529348,0.657941;0.168478x0.222059)
# Height            AxesSubplot(0.731522,0.657941;0.168478x0.222059)
# Whole weight         AxesSubplot(0.125,0.391471;0.168478x0.222059)
# Shucked weight    AxesSubplot(0.327174,0.391471;0.168478x0.222059)
# Viscera weight    AxesSubplot(0.529348,0.391471;0.168478x0.222059)
# Shell weight      AxesSubplot(0.731522,0.391471;0.168478x0.222059)
# Rings                   AxesSubplot(0.125,0.125;0.168478x0.222059)
# dtype: object

# %%
observations:
    
Height, Rings high outliers are present

Length, Whole weight, Shucked weight, Viscera weight, Shell weight moderate outliers are present

# %% [markdown]
# ## Skewness Checking

# %%
sns.distplot(df['Sex'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Density'>

# %%
sns.distplot(df['Length'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sns.distplot(df['Diameter'])
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
sns.distplot(df['Height'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.distplot(df['Whole weight'])
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %%
sns.distplot(df['Shucked weight'])
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Density'>

# %%
sns.distplot(df['Viscera weight'])
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %%
sns.distplot(df['Shell weight'])
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %%
sns.distplot(df['Rings'])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %% [markdown]
# Observations:
#
# Looking at the above distribution plots we can see that there is skewness due to the outliers which we saw in the boxplot. Still there are many that are showing a bell shape curve indicating a normal distribution.

# %% [markdown]
# ## Histogram

# %%
plt.rcParams['figure.figsize'] = (15,15)
df.hist(bins = 30, density = 'True', label = 'Value',histtype = 'stepfilled', grid=False)
plt.tight_layout()
plt.show()

# %%
In histogram we can see if any section is empty such as in Rings 15 number there was not enough data collected also we can see the skewness.

# %%
df.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
Observations:

Skewness threshold usually taken as -0.5 to 0.5

referring the above distplot and histogram graphs and values we can infer:
    
highly skewed :  Height, Rings
moderately skewed : Length, Diameter, Whole weight, Shucked weight, Viscera weight, Shell weight

# %% [markdown]
# ## MultiCollinearity with Variance Inflation Factor

# %%
df1=pd.DataFrame(data=df)       # copying the dataframe
df1
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
x1=df1.iloc[:,:-1]
y1=df1.iloc[:,-1]

# %%
x1
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# ...

# %%
y1
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
x1.shape
# Out:
# (4177, 8)

# %%
y1.shape
# Out:
# (4177,)

# %%
x1.shape[1]    # 8 number of columns
# Out:
# 8

# %%
# importing required libraries
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(x1):
    vif=pd.DataFrame()
    vif["variables"]=x1.columns
    vif["VIF FACTOR"]=[variance_inflation_factor(x1.values,i) for i in range(x1.shape[1])]
    return(vif)

# %%
calc_vif(x1)
# Out:
#         variables  VIF FACTOR
# 0             Sex    2.555356
# 1          Length  700.488988
# 2        Diameter  749.121626
# 3          Height   42.128924
# 4    Whole weight  421.652484
# 5  Shucked weight  101.674946
# 6  Viscera weight   63.585627
# 7    Shell weight   81.873737

# %% [markdown]
# in between length and diameter in corr heatmap length is giving less contribution hence it is dropped in VIF and changes in VIF are as follows

# %%
x1=df1.drop(['Length'],axis=1)

# %%
calc_vif(x1)
# Out:
#         variables  VIF FACTOR
# 0             Sex    2.545465
# 1        Diameter   62.345278
# 2          Height   42.686825
# 3    Whole weight  435.305438
# 4  Shucked weight  117.303502
# 5  Viscera weight   64.541685
# 6    Shell weight   81.720804
# 7           Rings   21.594824

# %% [markdown]
# in between whole weight and shucked weight in corr heatmap shucked weight is giving less contribution hence it is dropped in VIF and changes in VIF are as follows

# %%
x1=df1.drop(['Length','Shucked weight'],axis=1)

# %%
calc_vif(x1)
# Out:
#         variables  VIF FACTOR
# 0             Sex    2.537687
# 1        Diameter   58.307130
# 2          Height   42.683678
# 3    Whole weight  131.971592
# 4  Viscera weight   59.346850
# 5    Shell weight   57.219277
# 6           Rings   18.686253

# %% [markdown]
# Observations:
#
# From the above after removal of length and shucked weight we can see that the VIF decreases drastically. Although VIF is still high in the other columns we will need the other columns to predict the label Rings (Age) in our dataset

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Data cleaning:

# %% [markdown]
# ### Dropping a column

# %%
referring all the above EDA steps we have decided to drop 2 columns:
    
Length:
    
- in between length and diameter in correlation heatmap, length is giving less contribution
- moderate outliers are present
- moderately skewed observing the distplot, histogram and df.skew()
- High VIF factor

Shucked weight:

- in between whole weight and shucked weight in correlation heatmap, shucked weight is giving less contribution and its giving the least contribution compared to the other variables.
- moderate outliers are present
- moderately skewed observing the distplot, histogram and df.skew()
- High VIF factor

# %%
df.drop(['Length','Shucked weight'],axis=1,inplace=True)
df
# Out:
#       Sex  Diameter  Height  Whole weight  Viscera weight  Shell weight  Rings
# 0       2     0.365   0.095        0.5140          0.1010        0.1500     15
# 1       2     0.265   0.090        0.2255          0.0485        0.0700      7
# 2       0     0.420   0.135        0.6770          0.1415        0.2100      9
# 3       2     0.365   0.125        0.5160          0.1140        0.1550     10
# 4       1     0.255   0.080        0.2050          0.0395        0.0550      7
# ...   ...       ...     ...           ...             ...           ...    ...
# 4172    0     0.450   0.165        0.8870          0.2390        0.2490     11
# 4173    2     0.440   0.135        0.9660          0.2145        0.2605     10
# 4174    2     0.475   0.205        1.1760          0.2875        0.3080      9
# 4175    0     0.485   0.150        1.0945          0.2610        0.2960     10
# 4176    2     0.555   0.195        1.9485          0.3765        0.4950     12
#
# [4177 rows x 7 columns]

# %%
calc_vif(df)
# Out:
#         variables  VIF FACTOR
# 0             Sex    2.537687
# 1        Diameter   58.307130
# 2          Height   42.683678
# 3    Whole weight  131.971592
# 4  Viscera weight   59.346850
# 5    Shell weight   57.219277
# 6           Rings   18.686253

# %%
df.corr()
# Out:
#                      Sex  Diameter    Height  Whole weight  Viscera weight  \
# Sex             1.000000 -0.038874 -0.042077     -0.021391       -0.032067
# Diameter       -0.038874  1.000000  0.833684      0.925452        0.899724
# Height         -0.042077  0.833684  1.000000      0.819221        0.798319
# Whole weight   -0.021391  0.925452  0.819221      1.000000        0.966375
# Viscera weight -0.032067  0.899724  0.798319      0.966375        1.000000
# Shell weight   -0.034854  0.905330  0.817338      0.955355        0.907656
# Rings          -0.034627  0.574660  0.557467      0.540390        0.503819
#
#                 Shell weight     Rings
# Sex                -0.034854 -0.034627
# Diameter            0.905330  0.574660
# Height              0.817338  0.557467
# Whole weight        0.955355  0.540390
# Viscera weight      0.907656  0.503819
# Shell weight        1.000000  0.627574
# Rings               0.627574  1.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Removing outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#            Sex  Diameter    Height  Whole weight  Viscera weight  \
# 0     1.151980  0.432149  1.064424      0.641898        0.726212
# 1     1.151980  1.439929  1.183978      1.230277        1.205221
# 2     1.280690  0.122130  0.107991      0.309469        0.356690
# 3     1.151980  0.432149  0.347099      0.637819        0.607600
# 4     0.064355  1.540707  1.423087      1.272086        1.287337
# ...        ...       ...       ...           ...             ...
# 4172  1.280690  0.424464  0.609334      0.118813        0.532900
# 4173  1.151980  0.323686  0.107991      0.279929        0.309362
# 4174  1.151980  0.676409  1.565767      0.708212        0.975413
# 4175  1.280690  0.777187  0.250672      0.541998        0.733627
# 4176  1.151980  1.482634  1.326659      2.283681        1.787449
#
#       Shell weight     Rings
# 0         0.638217  1.571544
# 1         1.212987  0.910013
# 2         0.207139  0.289624
# 3         0.602294  0.020571
# 4         1.320757  0.910013
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  166,  166,
#         167,  168,  170,  181,  232,  236,  236,  237,  238,  270,  275,
#         277,  278,  294,  310,  313,  314,  334,  351,  355,  358,  358,
#         362,  375,  416,  417,  428,  431,  433,  469,  478,  480,  501,
#         526,  530,  572,  628,  673,  674,  675,  678,  694,  696,  719,
#         720,  744,  754,  756,  811,  891,  891, 1048, 1051, 1052, 1204,
#        1206, 1207, 1207, 1207, 1209, 1257, 1417, 1422, 1427, 1427, 1428,
#        1429, 1757, 1759, 1762, 1762, 1763, 1763, 1987, 2051, 2090, 2108,
#        2108, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209, 2274,
#        2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2436, 2459,
#        2471, 2623, 2624, 2624, 2709, 2710, 2810, 2811, 2811, 2863, 2863,
#        3008, 3140, 3148, 3149, 3149, 3151, 3151, 3188, 3193, 3280, 3359,
#        3427, 3427, 3599, 3628, 3715, 3715, 3715, 3800, 3837, 3899, 3924,
# ...

# %%
#row and column
z.iloc[6,6]
# Out:
# 3.12251641377204

# %%
z.shape
# Out:
# (4177, 7)

# %%
len(np.where(z>3)[0])
# Out:
# 148

# %%
# removing outliers
df_new=df[(z<3).all(axis=1)]
print("Old Dataframe",df.shape)
print("New Dataframe",df_new.shape)
print("total_dropped_rows",df.shape[0] - df_new.shape[0])
# Out:
# Old Dataframe (4177, 7)
# New Dataframe (4050, 7)
# total_dropped_rows 127

# %% [markdown]
# Z score method to get rid of outliers present in our dataset that are not in the acceptable range of +/-3 zscore value.

# %% [markdown]
# ## Percentage data loss:

# %%
loss_percent=(4177-4050)/4177*100
print(loss_percent,'%')
# Out:
# 3.040459660043093 %

# %% [markdown]
# After removing the outliers we are checking the data loss percentage by comparing the rows in our original data set and the new data set
#
# 3.04% data loss is acceptable.

# %% [markdown]
# ### df_new is the new data set after 2 columns are removed and all the outliers (with z<3 z score) are removed

# %% [markdown]
# ## Splitting the dataset into Features and Target

# %%
X = df_new.iloc[:,:-1]
y = df_new.iloc[:,-1]

# %%
X
# Out:
#       Sex  Diameter  Height  Whole weight  Viscera weight  Shell weight
# 0       2     0.365   0.095        0.5140          0.1010        0.1500
# 1       2     0.265   0.090        0.2255          0.0485        0.0700
# 2       0     0.420   0.135        0.6770          0.1415        0.2100
# 3       2     0.365   0.125        0.5160          0.1140        0.1550
# 4       1     0.255   0.080        0.2050          0.0395        0.0550
# ...   ...       ...     ...           ...             ...           ...
# 4172    0     0.450   0.165        0.8870          0.2390        0.2490
# 4173    2     0.440   0.135        0.9660          0.2145        0.2605
# 4174    2     0.475   0.205        1.1760          0.2875        0.3080
# 4175    0     0.485   0.150        1.0945          0.2610        0.2960
# 4176    2     0.555   0.195        1.9485          0.3765        0.4950
#
# [4050 rows x 6 columns]

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4050, dtype: int64

# %%
X.skew()
# Out:
# Sex              -0.098078
# Diameter         -0.598478
# Height           -0.248237
# Whole weight      0.388193
# Viscera weight    0.455795
# Shell weight      0.365540
# dtype: float64

# %%
Observations:

Since the skewness is almost within permissible ranges and the outlier data are a real value we have proceeded with the X independant variables as it is.

# %% [markdown]
# ### Scaling the independant variable (x) to get all the columns in a standard scale

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x1=sc.fit_transform(X)
x1
# Out:
# array([[ 1.15682064, -0.42176554, -1.16116187, -0.63340556, -0.72366849,
#         -0.63247034],
#        [ 1.15682064, -1.45625586, -1.29557866, -1.25426925, -1.22524216,
#         -1.25071252],
#        [-1.28652934,  0.14720414, -0.08582761, -0.28262296, -0.33674023,
#         -0.1687887 ],
#        ...,
#        [ 1.15682064,  0.71617382,  1.79600736,  0.79124525,  1.05811226,
#          0.58855797],
#        [-1.28652934,  0.81962285,  0.31742274,  0.61585395,  0.80493698,
#          0.49582164],
#        [ 1.15682064,  1.54376608,  1.5271738 ,  2.45369653,  1.90839906,
#          2.03369908]])

# %%
since the different columns were out of scale we performed scaling operation on all the independant variables columns to bring it into the same scale.

We used Standard Scaler method to ensure all my independant variables columns have been standardized.

# %% [markdown]
# reassigning column names

# %%
X.columns
# Out:
# Index(['Sex', 'Diameter', 'Height', 'Whole weight', 'Viscera weight',
#        'Shell weight'],
#       dtype='object')

# %%
x = pd.DataFrame(x1,columns=X.columns)

# %%
x
# Out:
#            Sex  Diameter    Height  Whole weight  Viscera weight  Shell weight
# 0     1.156821 -0.421766 -1.161162     -0.633406       -0.723668     -0.632470
# 1     1.156821 -1.456256 -1.295579     -1.254269       -1.225242     -1.250713
# 2    -1.286529  0.147204 -0.085828     -0.282623       -0.336740     -0.168789
# 3     1.156821 -0.421766 -0.354661     -0.629101       -0.599469     -0.593830
# 4    -0.064854 -1.559705 -1.564412     -1.298386       -1.311226     -1.366633
# ...        ...       ...       ...           ...             ...           ...
# 4045 -1.286529  0.457551  0.720673      0.169306        0.594754      0.132604
# 4046  1.156821  0.354102 -0.085828      0.339317        0.360686      0.221477
# 4047  1.156821  0.716174  1.796007      0.791245        1.058112      0.588558
# 4048 -1.286529  0.819623  0.317423      0.615854        0.804937      0.495822
# 4049  1.156821  1.543766  1.527174      2.453697        1.908399      2.033699
#
# [4050 rows x 6 columns]

# %% [markdown]
# now the data is ready for Machine learing

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ### Since the y (Target) has continuous values we will use Linear Regression model

# %% [markdown]
# ## Finding Best Random State

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
lr = LinearRegression()

# %%
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20,random_state=i)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    print(f"At random state {i}, the training accuracy is : {r2_score(y_train,pred_train)}")
    print(f"At random state {i}, the testing accuracy is :  {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is : 0.4543547223429292
# At random state 1, the testing accuracy is :  0.4520215265531826
#
#
# At random state 2, the training accuracy is : 0.4547751723221598
# At random state 2, the testing accuracy is :  0.4481851181430663
#
#
# At random state 3, the training accuracy is : 0.4534516364797737
# At random state 3, the testing accuracy is :  0.45532208374479444
#
#
# At random state 4, the training accuracy is : 0.45348125036522535
# At random state 4, the testing accuracy is :  0.45393086121985027
#
#
# At random state 5, the training accuracy is : 0.46016217712990537
# At random state 5, the testing accuracy is :  0.4262160767739057
#
#
# At random state 6, the training accuracy is : 0.45688576598348185
# At random state 6, the testing accuracy is :  0.4420715102655094
#
#
# At random state 7, the training accuracy is : 0.4577032853971392
# At random state 7, the testing accuracy is :  0.43632701015611774
#
#
# ...

# %% [markdown]
# Hence we chose random state 111 since both training and testing accuracy is close by and higher in value compared to others

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20,random_state=111)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test = lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.4592576466121676

# %% [markdown]
# Since the r2_score is low we will try with various other Regressors at random state 111

# %% [markdown]
# ### Cross Validation of the model

# %%
from sklearn.model_selection import cross_val_score

# %%
train_accuracy = r2_score(y_train,pred_train)
test_accuracy = r2_score(y_test,pred_test)

for j in range(2,10):
    cv_score = cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean}")
    print(f"accuracy score for training is {train_accuracy}")
    print(f"accuracy score for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.45034800997599156
# accuracy score for training is -0.4253815882535006
# accuracy score for testing is 0.4592576466121676
#
#
# At cross fold 3 the cv score is 0.43452225180600995
# accuracy score for training is -0.4253815882535006
# accuracy score for testing is 0.4592576466121676
#
#
# At cross fold 4 the cv score is 0.34690354375792903
# accuracy score for training is -0.4253815882535006
# accuracy score for testing is 0.4592576466121676
#
#
# At cross fold 5 the cv score is 0.34819343213987397
# accuracy score for training is -0.4253815882535006
# accuracy score for testing is 0.4592576466121676
#
#
# At cross fold 6 the cv score is 0.35760548917312973
# accuracy score for training is -0.4253815882535006
# accuracy score for testing is 0.4592576466121676
#
#
# At cross fold 7 the cv score is 0.36705536696532465
# accuracy score for training is -0.4253815882535006
# accuracy score for testing is 0.4592576466121676
#
#
# ...

# %% [markdown]
# cv = 7 is chosen since it shows the most cv score while cv value should be usually in the higher range.
# But the accuracy sccore is below 50% hence we will test with other regressors too.

# %% [markdown]
# We will draw the linear regression plot to see the best fit line

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_test, color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual charges', fontsize=14)
plt.ylabel('Predicted charges', fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# The best fit line doesnt seem to be covering more than 50% of the points

# %%
# importing all the required libraries

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
# creating a function to run all the regressors

def regressor(model, x, y):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=111)
    
    # Training the model
    model.fit(x_train, y_train)
    
    # Predicting y_test
    pred = model.predict(x_test)
    
    # Root Mean Square Error (RMSE)
    rmse = mean_squared_error(y_test, pred, squared=False)
    print("Root Mean Square Error is:", rmse)
    
    # R2 score
    r2 = r2_score(y_test, pred, multioutput='variance_weighted')*100
    print("R2 Score is:", r2)
    
    # Cross Validation Score
    cv_score = (cross_val_score(model, x, y, cv=5).mean())*100
    print("Cross Validation Score is:", cv_score)
    
    # Result of r2 score - cv score
    result = r2 - cv_score
    print("R2 Score - Cross Validation Score is", result)

# %% [markdown]
# ### Linear Regression

# %%
model=LinearRegression()
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 2.0480132293953295
# R2 Score is: 45.92576466121676
# Cross Validation Score is: 34.819343213987395
# R2 Score - Cross Validation Score is 11.106421447229366

# %% [markdown]
# ### L1 -- Lasso Regression

# %%
model=Lasso(alpha=0.0001)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 2.048008765073039
# R2 Score is: 45.92600040632581
# Cross Validation Score is: 34.820009085495485
# R2 Score - Cross Validation Score is 11.105991320830327

# %% [markdown]
# ### L2 -- Ridge Regression

# %%
model=Ridge(alpha=0.0001)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 2.0480132309371597
# R2 Score is: 45.92576457979807
# Cross Validation Score is: 34.81934272360788
# R2 Score - Cross Validation Score is 11.106421856190188

# %% [markdown]
# ### Elastic Net

# %%
model=ElasticNet(alpha=0.0001)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 2.048014211497105
# R2 Score is: 45.9257127998181
# Cross Validation Score is: 34.81884518872511
# R2 Score - Cross Validation Score is 11.106867611092987

# %% [markdown]
# ### Support Vector Regression

# %%
model=SVR(kernel='rbf')
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 1.9976979940627304
# R2 Score is: 48.550099585531704
# Cross Validation Score is: 43.260514030725375
# R2 Score - Cross Validation Score is 5.2895855548063295

# %%
model=SVR(kernel='poly')
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 2.2539031771653093
# R2 Score is: 34.50692481260151
# Cross Validation Score is: 25.709166224840967
# R2 Score - Cross Validation Score is 8.797758587760544

# %%
model=SVR(kernel='linear')
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 2.095094636656979
# R2 Score is: 43.41098147981729
# Cross Validation Score is: 35.74158909602133
# R2 Score - Cross Validation Score is 7.669392383795959

# %% [markdown]
# ### Decision Tree Regressor

# %%
model=DecisionTreeRegressor(random_state=111)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 2.8201217030038057
# R2 Score is: -2.532270130035497
# Cross Validation Score is: -13.902442771108865
# R2 Score - Cross Validation Score is 11.370172641073367

# %% [markdown]
# ### Random Forest Regressor

# %%
model=RandomForestRegressor()
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 1.9775273873959964
# R2 Score is: 49.583825940250506
# Cross Validation Score is: 38.83191742271185
# R2 Score - Cross Validation Score is 10.75190851753866

# %% [markdown]
# ### K Neighbors Regressor

# %%
model=KNeighborsRegressor()
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 2.035487626231909
# R2 Score is: 46.585175635454966
# Cross Validation Score is: 35.245010473175576
# R2 Score - Cross Validation Score is 11.34016516227939

# %% [markdown]
# ### SGD Regressor

# %%
model=SGDRegressor(penalty='l1', learning_rate='optimal')
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 2.6765619364648483
# R2 Score is: 7.640948005168102
# Cross Validation Score is: 32.45068221259274
# R2 Score - Cross Validation Score is -24.809734207424636

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
model=GradientBoostingRegressor()
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 1.978125918487687
# R2 Score is: 49.553302758150984
# Cross Validation Score is: 40.96547112185645
# R2 Score - Cross Validation Score is 8.587831636294531

# %% [markdown]
# ### Ada Boost Regressor

# %%
model=AdaBoostRegressor(random_state=111)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 2.207468257919332
# R2 Score is: 37.17770378528476
# Cross Validation Score is: 17.517660474722106
# R2 Score - Cross Validation Score is 19.660043310562656

# %% [markdown]
# ### Extra Trees Regressor

# %%
model=ExtraTreesRegressor(n_estimators=200, max_features='sqrt', n_jobs=6)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 1.9746890206802339
# R2 Score is: 49.72844785051489
# Cross Validation Score is: 39.039893206588395
# R2 Score - Cross Validation Score is 10.688554643926494

# %% [markdown]
# Comparing all the above the Support Vector Regressor gives the best results since the R2 Score - Cross Validation Score is 5.289 and at the same time the accuracy is also 48.55%

# %% [markdown]
# ## Hyper parameter tuning

# %%
# Support Vector Regressor

# %%
# creating parameters list to pass into GridSearchCV
parameters = {'kernel' : ['poly', 'linear', 'rbf'],
              'C': [2.0, 3.0, 4.0],
              'gamma' : ['scale', 'auto'],
              'epsilon': [0.2, 0.3, 0.4],
              'shrinking' : [True, False]}

# %%
GCV = GridSearchCV(SVR(), parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [2.0, 3.0, 4.0], 'epsilon': [0.2, 0.3, 0.4],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['poly', 'linear', 'rbf'],
#                          'shrinking': [True, False]})

# %%
GCV.best_params_          # printing best parameters found by GridSearchCV
# Out:
# {'C': 3.0,
#  'epsilon': 0.4,
#  'gamma': 'auto',
#  'kernel': 'rbf',
#  'shrinking': False}

# %% [markdown]
# We got the best parameters using Gridsearch CV

# %%
type(GCV)
# Out:
# sklearn.model_selection._search.GridSearchCV

# %%
GCV.best_estimator_
# Out:
# SVR(C=3.0, epsilon=0.4, gamma='auto', shrinking=False)

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)              # predicting with best parameters
best_r2=r2_score(y_test,GCV_pred,multioutput='variance_weighted')*100   # checking final r2_score
print("R2 score for the Best Model is:", best_r2)
# Out:
# R2 score for the Best Model is: 49.50743932630978

# %%
We used Hyper Parameter Tuning on the final model and obtained the r2_score.

# %% [markdown]
# # Saving the model in pickle Format

# %%
# pickeling or serialization of a file
import pickle
filename = 'Abalone_Case_Study.pkl'
pickle.dump(GCV.best_estimator_, open(filename, 'wb'))

# %%
Saving the best regression model using pickle

# %% [markdown]
# # Prediction Conclusion:

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(GCV.best_estimator_.predict(x_test))
df_comparison = pd.DataFrame({"original":a,"predicted":predicted},index= range(len(a)))
df_comparison
# Out:
#      original  predicted
# 0          11   9.836103
# 1          12  11.070618
# 2          11  10.621604
# 3          12  11.327419
# 4           9   8.915386
# ..        ...        ...
# 805         8  10.393991
# 806         8   7.843863
# 807         8   7.622534
# 808        11  10.743236
# 809         7   7.809200
#
# [810 rows x 2 columns]

# %%
Predicting the rings of each abalone which will lead us to the age of that abalone
